# %%
PATH_SERVER_LOG = './data/iota_log_srv.log'

# %% [markdown]
# ## UDP network deamon

# %%
IOTA_SVR_ADDR = '0.0.0.0'
IOTA_SVR_PORT_LTN = 55555    # need to be same in gateway, e.g. Arduino.ino

# %% [markdown]
# ## Real-time data bus

# %%
SOCK_TCP_MCUSRV_PORT = "18087"
SOCK_TCP_MCUSRV_PUB = f"tcp://*:{SOCK_TCP_MCUSRV_PORT}"
SOCK_TCP_MCUSRV_SUB = f"tcp://localhost:{SOCK_TCP_MCUSRV_PORT}"

SOCK_TCP_REPLAY_PORT = "18086"
SOCK_TCP_REPLAY_PUB = f"tcp://*:{SOCK_TCP_REPLAY_PORT}"
SOCK_TCP_REPLAY_SUB = f"tcp://localhost:{SOCK_TCP_REPLAY_PORT}"

IN_SOCK_BUF_SIZE = 2048
IN_SOCK_TIMEOUT_SEC = 1
